# %%
import requests
import json

# %%
url = "http://127.0.0.1:8000/"
username = "test"
password = "test"

# %%
# 获取令牌
r = requests.post(
    url + "token",
    data={"username": username, "password": password},
    headers={"accept": "application/json"}
)
token = r.json()["access_token"]

# %%
# 查询函数
def query_test(name):
    """查询对应类型的数据"""
    r = requests.get(
        url + name,
        headers={"Authorization": "Bearer " + token}
    )
    return r.json()

# %%
# 行情订阅
r = requests.post(
    url + "tick/" + "cu2112.SHFE",
    headers={"Authorization": "Bearer " + token}
)

# %%
# 批量查询
for name in ["tick", "contract", "account", "position", "order", "trade"]:
    data = query_test(name)
    print(name + "-" * 20)
    if data:
        print(data[0])
# Out:
# tick--------------------
# {'gateway_name': 'CTP', 'symbol': 'cu2112', 'exchange': 'SHFE', 'datetime': '2021-08-12 22:02:04+08:00', 'name': '铜2112', 'volume': 4073, 'open_interest': 25240.0, 'last_price': 69910.0, 'last_volume': 0, 'limit_up': 74900.0, 'limit_down': 63810.0, 'open_price': 69520.0, 'high_price': 70480.0, 'low_price': 69450.0, 'pre_close': 69630.0, 'bid_price_1': 69890.0, 'bid_price_2': 0, 'bid_price_3': 0, 'bid_price_4': 0, 'bid_price_5': 0, 'ask_price_1': 69910.0, 'ask_price_2': 0, 'ask_price_3': 0, 'ask_price_4': 0, 'ask_price_5': 0, 'bid_volume_1': 1, 'bid_volume_2': 0, 'bid_volume_3': 0, 'bid_volume_4': 0, 'bid_volume_5': 0, 'ask_volume_1': 5, 'ask_volume_2': 0, 'ask_volume_3': 0, 'ask_volume_4': 0, 'ask_volume_5': 0, 'localtime': None, 'vt_symbol': 'cu2112.SHFE'}
# contract--------------------
# {'gateway_name': 'CTP', 'symbol': 'sc2209', 'exchange': 'INE', 'name': '原油2209', 'product': '期货', 'size': 1000, 'pricetick': 0.1, 'min_volume': 1, 'stop_supported': False, 'net_position': False, 'history_data': False, 'option_strike': 0, 'option_underlying': '', 'option_type': None, 'option_expiry': None, 'option_portfolio': '', 'option_index': '', 'vt_symbol': 'sc2209.INE'}
# account--------------------
# {'gateway_name': 'CTP', 'accountid': '000300', 'balance': 25808245.032500003, 'frozen': 0.0, 'available': 25684755.832500003, 'vt_accountid': 'CTP.000300'}
# position--------------------
# {'gateway_name': 'CTP', 'symbol': 'cu2109', 'exchange': 'SHFE', 'direction': '多', 'volume': 3, 'frozen': 0, 'price': 69590.0, 'pnl': 3600.0, 'yd_volume': 1, 'vt_symbol': 'cu2109.SHFE', 'vt_positionid': 'cu2109.SHFE.多'}
# order--------------------
# {'gateway_name': 'CTP', 'symbol': 'cu2109', 'exchange': 'SHFE', 'orderid': '1_-511046300_1', 'type': '限价', 'direction': '多', 'offset': '开', 'price': 69700.0, 'volume': 1, 'traded': 1, 'status': '全部成交', 'datetime': '2021-08-10 17:16:39+08:00', 'reference': '', 'vt_symbol': 'cu2109.SHFE', 'vt_orderid': 'CTP.1_-511046300_1'}
# trade--------------------
# {'gateway_name': 'CTP', 'symbol': 'cu2109', 'exchange': 'SHFE', 'orderid': '1_-511046300_2', 'tradeid': '        2424', 'direction': '空', 'offset': '开', 'price': 69770.0, 'volume': 1, 'datetime': '2021-08-10 17:16:41+08:00', 'vt_symbol': 'cu2109.SHFE', 'vt_orderid': 'CTP.1_-511046300_2', 'vt_tradeid': 'CTP.        2424'}

# %%
# 委托测试
req = {
    "symbol": "cu2109",
    "exchange": "SHFE",
    "direction": "多",
    "type": "限价",
    "volume": 1,
    "price": 69500,
    "offset": "开",
    "reference": "WebTrader"
}

r = requests.post(
    url + "order",
    json=req,
    headers={"Authorization": "Bearer " + token}
)
vt_orderid = r.json()

print(vt_orderid)
# Out:
# CTP.1_469905582_3

# %%
# 撤单测试
r = requests.delete(
    url + "order/" + vt_orderid,
    headers={"Authorization": "Bearer " + token}
)

# %%
# Weboscket测试
from websocket import create_connection

ws = create_connection("ws://127.0.0.1:8000/ws/")

while True:
    result =  ws.recv()
    print("Received '%s'" % result)

ws.close()
# Out:
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:16+08:00", "name": "铜2112", "volume": 4073, "open_interest": 25240.0, "last_price": 69910.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69890.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 1, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:16.500000+08:00", "name": "铜2112", "volume": 4073, "open_interest": 25240.0, "last_price": 69910.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69890.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 1, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3600.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -300.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2340.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4680.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1530.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2040.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:19.500000+08:00", "name": "铜2112", "volume": 4073, "open_interest": 25240.0, "last_price": 69910.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69890.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 1, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 3, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25808245.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:20+08:00", "name": "铜2112", "volume": 4073, "open_interest": 25240.0, "last_price": 69910.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69890.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 1, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 3, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:21+08:00", "name": "铜2112", "volume": 4073, "open_interest": 25240.0, "last_price": 69910.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69890.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 1, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 1, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3600.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -300.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2360.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4720.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1530.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2040.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:23+08:00", "name": "铜2112", "volume": 4073, "open_interest": 25240.0, "last_price": 69910.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69890.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69920.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 2, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 8, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25808265.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3600.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -300.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2360.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4720.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1530.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2040.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:27.500000+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69880.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 5, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 1, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25808225.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:28+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69880.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 5, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3450.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -250.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2380.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4760.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1530.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2040.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25808245.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3600.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -300.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2360.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4720.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1620.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2160.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:34+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69880.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 5, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25808175.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3600.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -300.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2400.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4800.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1620.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2160.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:38+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69890.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 2, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 4, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:39+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69880.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 5, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 4, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:39.500000+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69880.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 3, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25808295.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:41.500000+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69870.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 5, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3450.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -250.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2380.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4760.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1620.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2160.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:42+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69880.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 2, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25808195.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:45+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69880.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 2, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3600.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -300.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2380.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4760.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1620.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2160.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:47+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69880.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 2, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 6, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25808295.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:50+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69880.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 2, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3600.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -300.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2380.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4760.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1680.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2240.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25808335.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:53+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69880.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 2, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:53.500000+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69870.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 13, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:54+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69870.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 12, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 6, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3450.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -250.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2400.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4800.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1680.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2240.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:56+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69870.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 12, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 6, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25808295.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:56.500000+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69870.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69910.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 12, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 6, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:02:57+08:00", "name": "铜2112", "volume": 4075, "open_interest": 25238.0, "last_price": 69890.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69870.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69900.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 12, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 1, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# ...
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:03:16+08:00", "name": "铜2112", "volume": 4081, "open_interest": 25239.0, "last_price": 69870.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69850.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69870.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 1, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 1, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25807935.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:03:16.500000+08:00", "name": "铜2112", "volume": 4081, "open_interest": 25239.0, "last_price": 69870.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69850.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69870.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 1, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 3, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:03:17+08:00", "name": "铜2112", "volume": 4081, "open_interest": 25239.0, "last_price": 69870.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69850.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69870.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 1, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 5, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:03:17.500000+08:00", "name": "铜2112", "volume": 4082, "open_interest": 25239.0, "last_price": 69850.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69840.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69870.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 3, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 6, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:03:18+08:00", "name": "铜2112", "volume": 4082, "open_interest": 25239.0, "last_price": 69850.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69830.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69860.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 5, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 1, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 3000.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -100.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2400.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4800.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1680.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2240.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:03:18.500000+08:00", "name": "铜2112", "volume": 4082, "open_interest": 25239.0, "last_price": 69850.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69830.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69870.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 8, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 6, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eAccount.", "data": {"gateway_name": "CTP", "accountid": "000300", "balance": 25807935.032500003, "frozen": 0.0, "available": 25684755.832500003, "vt_accountid": "CTP.000300"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:03:20.500000+08:00", "name": "铜2112", "volume": 4082, "open_interest": 25239.0, "last_price": 69850.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69830.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69860.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 8, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 3, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "eTick.", "data": {"gateway_name": "CTP", "symbol": "cu2112", "exchange": "SHFE", "datetime": "2021-08-12 22:03:21+08:00", "name": "铜2112", "volume": 4082, "open_interest": 25239.0, "last_price": 69850.0, "last_volume": 0, "limit_up": 74900.0, "limit_down": 63810.0, "open_price": 69520.0, "high_price": 70480.0, "low_price": 69450.0, "pre_close": 69630.0, "bid_price_1": 69830.0, "bid_price_2": 0, "bid_price_3": 0, "bid_price_4": 0, "bid_price_5": 0, "ask_price_1": 69860.0, "ask_price_2": 0, "ask_price_3": 0, "ask_price_4": 0, "ask_price_5": 0, "bid_volume_1": 9, "bid_volume_2": 0, "bid_volume_3": 0, "bid_volume_4": 0, "bid_volume_5": 0, "ask_volume_1": 2, "ask_volume_2": 0, "ask_volume_3": 0, "ask_volume_4": 0, "ask_volume_5": 0, "localtime": null, "vt_symbol": "cu2112.SHFE"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 69590.0, "pnl": 2850.0, "yd_volume": 1, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109", "exchange": "SHFE", "direction": "空", "volume": 1, "frozen": 0, "price": 69770.0, "pnl": -50.0, "yd_volume": 0, "vt_symbol": "cu2109.SHFE", "vt_positionid": "cu2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "空", "volume": 2, "frozen": 0, "price": 5379.0, "pnl": -2400.0, "yd_volume": 2, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2110", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5379.0, "pnl": 4800.0, "yd_volume": 4, "vt_symbol": "rb2110.SHFE", "vt_positionid": "rb2110.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "空", "volume": 3, "frozen": 0, "price": 5307.0, "pnl": -1680.0, "yd_volume": 3, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.空"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "rb2109", "exchange": "SHFE", "direction": "多", "volume": 4, "frozen": 0, "price": 5307.0, "pnl": 2240.0, "yd_volume": 4, "vt_symbol": "rb2109.SHFE", "vt_positionid": "rb2109.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P72000", "exchange": "SHFE", "direction": "多", "volume": 3, "frozen": 0, "price": 3092.0, "pnl": 0.0, "yd_volume": 3, "vt_symbol": "cu2109P72000.SHFE", "vt_positionid": "cu2109P72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109P71000", "exchange": "SHFE", "direction": "多", "volume": 2, "frozen": 0, "price": 2332.0, "pnl": 0.0, "yd_volume": 2, "vt_symbol": "cu2109P71000.SHFE", "vt_positionid": "cu2109P71000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C72000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 364.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C72000.SHFE", "vt_positionid": "cu2109C72000.SHFE.多"}}'
# Received '{"topic": "ePosition.", "data": {"gateway_name": "CTP", "symbol": "cu2109C71000", "exchange": "SHFE", "direction": "多", "volume": 10, "frozen": 0, "price": 604.0, "pnl": 0.0, "yd_volume": 10, "vt_symbol": "cu2109C71000.SHFE", "vt_positionid": "cu2109C71000.SHFE.多"}}'
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-9-b6da9f603320> in <module>
#       5
#       6 while True:
# ----> 7     result =  ws.recv()
#       8     print("Received '%s'" % result)
#       9
#
# c:\vnstudio\lib\site-packages\websocket\_core.py in recv(self)
#     351         """
#     352         with self.readlock:
# --> 353             opcode, data = self.recv_data()
#     354         if opcode == ABNF.OPCODE_TEXT:
#     355             return data.decode("utf-8")
#
# c:\vnstudio\lib\site-packages\websocket\_core.py in recv_data(self, control_frame)
#     374             tuple of operation code and string(byte array) value.
#     375         """
# --> 376         opcode, frame = self.recv_data_frame(control_frame)
#     377         return opcode, frame.data
#     378
#
# c:\vnstudio\lib\site-packages\websocket\_core.py in recv_data_frame(self, control_frame)
#     393         """
#     394         while True:
# --> 395             frame = self.recv_frame()
#     396             if (isEnabledForTrace()):
#     397                 trace("++Rcv raw: " + repr(frame.format()))
#
# c:\vnstudio\lib\site-packages\websocket\_core.py in recv_frame(self)
#     432         self.frame_buffer.recv_frame(): ABNF frame object
#     433         """
# --> 434         return self.frame_buffer.recv_frame()
#     435
#     436     def send_close(self, status=STATUS_NORMAL, reason=bytes('', encoding='utf-8')):
#
# c:\vnstudio\lib\site-packages\websocket\_abnf.py in recv_frame(self)
#     337             # Header
#     338             if self.has_received_header():
# --> 339                 self.recv_header()
#     340             (fin, rsv1, rsv2, rsv3, opcode, has_mask, _) = self.header
#     341
#
# c:\vnstudio\lib\site-packages\websocket\_abnf.py in recv_header(self)
#     293
#     294     def recv_header(self):
# --> 295         header = self.recv_strict(2)
#     296         b1 = header[0]
#     297         fin = b1 >> 7 & 1
#
# c:\vnstudio\lib\site-packages\websocket\_abnf.py in recv_strict(self, bufsize)
#     372             # buffers allocated and then shrunk, which results in
#     373             # fragmentation.
# --> 374             bytes_ = self.recv(min(16384, shortage))
#     375             self.recv_buffer.append(bytes_)
#     376             shortage -= len(bytes_)
#
# c:\vnstudio\lib\site-packages\websocket\_core.py in _recv(self, bufsize)
#     516     def _recv(self, bufsize):
#     517         try:
# --> 518             return recv(self.sock, bufsize)
#     519         except WebSocketConnectionClosedException:
#     520             if self.sock:
#
# c:\vnstudio\lib\site-packages\websocket\_socket.py in recv(sock, bufsize)
#     113             bytes_ = sock.recv(bufsize)
#     114         else:
# --> 115             bytes_ = _recv()
#     116     except socket.timeout as e:
#     117         message = extract_err_message(e)
#
# c:\vnstudio\lib\site-packages\websocket\_socket.py in _recv()
#      90     def _recv():
#      91         try:
# ---> 92             return sock.recv(bufsize)
#      93         except SSLWantReadError:
#      94             pass
#
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
